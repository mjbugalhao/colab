# %% [markdown]
# <a href="https://colab.research.google.com/github/mjbugalhao/colab/blob/main/MyFirstColabNotebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
print(time.ctime())
# Out:
# Sun Sep 29 13:24:53 2024

# %% [markdown]
# This is **bold**.
# This is *italic*.
# This is ~strikethrough~.
#
# $\sqrt{3x-1}+(1+x)^2$

# %%
# %%shell
# # Declare the shell variable
# message='A Great Tutorial on Colab by Tutorialspoint!'
#
# # Use echo to display the message
# echo -e "$message\n"
# Out:
# A Great Tutorial on Colab by Tutorialspoint!

# %%
# %%shell
# # Declare the shell variable
# message='A Great Tutorial on Colab by Tutorialspoint!'
#
# # Use echo to display the message
# echo -e "$message\n$message"
# Out:
# A Great Tutorial on Colab by Tutorialspoint!
# A Great Tutorial on Colab by Tutorialspoint!

# %%
# !wget https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv -P "/content/drive/My Drive/app"
# Out:
# --2024-09-29 19:22:34--  https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60302 (59K) [text/plain]
# Saving to: ‘/content/drive/My Drive/app/titanic.csv’
#
# titanic.csv         100%[===================>]  58.89K  --.-KB/s    in 0.01s
#
# 2024-09-29 19:22:34 (5.93 MB/s) - ‘/content/drive/My Drive/app/titanic.csv’ saved [60302/60302]

# %%
import pandas as pd
data = pd.read_csv("/content/drive/My Drive/app/titanic.csv")
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...
